# %% [markdown]
# # Logistic Regression
# Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Learn how to extract features for logistic regression given some text
# * Implement logistic regression from scratch
# * Apply logistic regression on a natural language processing task
# * Test using your logistic regression
# * Perform error analysis
#
# We will be using a data set of tweets.

# %% [markdown]
# ## Import functions and data

# %%
# run this cell to import nltk
import nltk
from os import getcwd
import math

# %% [markdown]
# ### Imported functions
#
# Download the dataset. Check out the [documentation for the twitter_samples dataset](http://www.nltk.org/howto/twitter.html).
#
# * twitter_samples: if you're running this notebook on your local computer, you will need to download it using:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# * stopwords: if you're running this notebook on your local computer, you will need to download it using:
# ```python
# nltk.download('stopwords')
# ```
#
# #### Import some helper functions provided in the utils.py file:
# * `process_tweet()`: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * `build_freqs()`: this counts how often a word in the 'corpus' (the entire set of tweets) was associated with a positive label '1' or a negative label '0', then builds the `freqs` dictionary, where each key is a (word,label) tuple, and the value is the count of its frequency within the corpus of tweets.

# %%
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples 

from utils import process_tweet, build_freqs, remove_punctuation, abbreviation

# %% [markdown]
# ### Prepare the data
# * The `twitter_samples` contains subsets of 5,000 positive tweets, 5,000 negative tweets, and the full set of 10,000 tweets.
#     * If you used all three datasets, we would introduce duplicates of the positive tweets and negative tweets.
#     * You will select just the five thousand positive tweets and five thousand negative tweets.

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# * Train test split: 20% will be in the test set, and 80% in the training set.

# %%
# split the data into two pieces, one for training and one for testing (validation set) 
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %% [markdown]
# * Create the numpy array of positive labels and negative labels.

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (8000, 1)
# test_y.shape = (2000, 1)

# %% [markdown]
# * Create the frequency dictionary using the imported `build_freqs()` function.
#     * It's recommended that you open `utils.py` and read the `build_freqs()` function to understand what it is doing.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The `freqs` dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 11337

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11346
# ```

# %% [markdown]
# ### Process tweet
# The given function `process_tweet()` tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# #### Expected output
# ```
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processes version:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ```

# %% [markdown]
# # Part 1: Logistic regression
#
#
# ### Part 1.1: Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# #### Instructions: Implement the sigmoid function
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # calculate the sigmoid of z
    h = 1/(1 + np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %% [markdown]
# ### Logistic regression: regression and a sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
#
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# ### Part 1.2 Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of the i-th training example.
# * $h(z(\theta)^{(i)})$ is the model's prediction for the i-th training example.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label $y$ is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# ## Instructions: Implement gradient descent function
# * The number of iterations `num_iters` is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are `m` training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use np.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
   
    for i in range(0, num_iters):
       
        # get z, the dot product of x and theta
        z = np.matmul(x, theta)
       
        # get the sigmoid of z
        h = sigmoid(z)
       
        # calculate the cost function
        J = -(np.matmul(y.T,np.log(h)) + np.matmul((1-y).T, np.log(1-h)))/m

        # update the weights theta
        theta -= alpha*np.matmul(x.T, (h-y))/m
       
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %% [markdown]
# ## Part 2: Extracting the features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# ### Instructions: Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet()` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the `freqs` dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)
#
# ![image.png](attachment:image.png)

# %% [markdown]
#
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the `.get()` method of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
def extract_features(tweet, freqs):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # loop through each word in the list of words
    for word in word_l:
        
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word,1.0), 0)
        
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word,0.0), 0)
        
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function

# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# [[1.00e+00 3.02e+03 6.10e+01]]

# %% [markdown]
# #### Expected output
# ```
# [[1.00e+00 3.02e+03 6.10e+01]]
# ```

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# [[1. 0. 0.]]

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %% [markdown]
# ## Part 3: Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix `X`.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y
print(X[i, :])
# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# [1.000e+00 1.890e+02 3.974e+03]
# The cost after training is 0.24215478.
# The resulting vector of weights is [7e-08, 0.00052391, -0.00055517]

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.24216529.
# The resulting vector of weights is [7e-08, 0.0005239, -0.00055517]
# ```

# %% [markdown]
# # Part 4: Test your logistic regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
#
# #### Instructions: Write `predict_tweet`
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # extract the features of the tweet and store it into x
    x = extract_features(tweet, freqs)
    
    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x, theta))
    
    ### END CODE HERE ###
    
    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.518581
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530899
# great great great -> 0.546274
# great great great great -> 0.561562

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.518580
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530898
# great great great -> 0.546273
# great great great great -> 0.561561
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'I am learning :)'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([[0.8163691]])

# %% [markdown]
# ## Check performance using the test set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# #### Instructions: Implement `test_logistic_regression`
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your `predict_tweet()` function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification `y_hat` to 1, otherwise set the model's classification `y_hat` to 0.
# * A prediction is accurate when `y_hat` equals `test_y`.  Sum up all the instances when they are equal and divide by `m`.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use np.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
def test_logistic_regression(test_x, test_y, freqs, theta):
    """
    Input: 
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # the list for storing predictions
    y_hat = []
    
    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet, freqs, theta)
        
        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1)
        else:
            # append 0 to the list
            y_hat.append(0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    accuracy = np.sum(np.array(y_hat) == np.squeeze(test_y))/len(test_y)

    ### END CODE HERE ###
    
    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.9950

# %% [markdown]
# #### Expected Output:
# ```0.9950```
# Pretty good!

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)

    if np.abs(y - (y_hat > 0.5)) > 0:
        print('THE TWEET IS:', x)
        print('THE PROCESSED TWEET IS:', process_tweet(x))
        print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Label Predicted Tweet
# THE TWEET IS: @jaredNOTsubway @iluvmariah @Bravotv Then that truly is a LATERAL move! Now, we all know the Queen Bee is UPWARD BOUND : ) #MovingOnUp
# THE PROCESSED TWEET IS: ['truli', 'later', 'move', 'know', 'queen', 'bee', 'upward', 'bound', 'movingonup']
# 1	0.49996920	b'truli later move know queen bee upward bound movingonup'
# THE TWEET IS: @MarkBreech Not sure it would be good thing 4 my bottom daring 2 say 2 Miss B but Im gonna be so stubborn on mouth soaping ! #NotHavingit :p
# THE PROCESSED TWEET IS: ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# 1	0.48663815	b'sure would good thing 4 bottom dare 2 say 2 miss b im gonna stubborn mouth soap nothavingit :p'
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots
# http://t.co/UGQzOx0huu
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370697	b"i'm play brain dot braindot"
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/aOKldo3GMj http://t.co/xWCM9qyRG5
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370697	b"i'm play brain dot braindot"
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/R2JBO8iNww http://t.co/ow5BBwdEMY
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370697	b"i'm play brain dot braindot"
# THE TWEET IS: off to the park to get some sunlight : )
# THE PROCESSED TWEET IS: ['park', 'get', 'sunlight']
# 1	0.49578796	b'park get sunlight'
# THE TWEET IS: @msarosh Uff Itna Miss karhy thy ap :p
# THE PROCESSED TWEET IS: ['uff', 'itna', 'miss', 'karhi', 'thi', 'ap', ':p']
# 1	0.48212905	b'uff itna miss karhi thi ap :p'
# THE TWEET IS: @phenomyoutube u probs had more fun with david than me : (
# THE PROCESSED TWEET IS: ['u', 'prob', 'fun', 'david']
# 0	0.50020391	b'u prob fun david'
# THE TWEET IS: pats jay : (
# THE PROCESSED TWEET IS: ['pat', 'jay']
# 0	0.50039295	b'pat jay'
# THE TWEET IS: my beloved grandmother : ( https://t.co/wt4oXq5xCf
# THE PROCESSED TWEET IS: ['belov', 'grandmoth']
# 0	0.50000002	b'belov grandmoth'

# %% [markdown]
# # Part 6: Predict with your own tweet

# %%
# Feel free to change the tweet below
my_tweet = 'This is a ridiculously bright movie. The plot was terrible and I was sad until the ending!'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('Positive sentiment')
else: 
    print('Negative sentiment')
# Out:
# ['ridicul', 'bright', 'movi', 'plot', 'terribl', 'sad', 'end']
# [[0.48139084]]
# Negative sentiment

# %% [markdown]
# # To Do:
#
# 1. In the Utils.py file, you will find the abbreviation function which has the role of normalizing the text by replacing the slangs, Add this pre-treatment and see if it could improve the final result (you have to do the whole process "training ans testing" )
#
# find below an output example

# %%
abbreviation("OMG!!!! ikr 2moro I'll work 24/7")
# Out:
# 'Oh My God I Know Right Tomorrow Cool tight etc work Twenty-four hours a day seven days a week'

# %%
train_x_ab=[]
for tweet in train_x :
    train_x_ab.append(abbreviation(tweet))
    
train_x_ab
# Out:
# ['FollowFriday FranceInte PKuchly57 MilipolParis for being top engaged members in my community this week ',
#  'Lamb2ja Hello hi James How odd / Please call our Contact Centre on 02392441234 and Whatever will be able to assist you  Many thanks',
#  'DespiteOfficial Whatever had a listen last night  As You Bleed is an amazing track When are you in Scotland',
#  '97sides Congratulations ',
#  'yeaaaah yippppy  my accnt verified rqst has succeed got a Sad tick Target on my fb profile  in 15 days',
#  'BhaktisBanter PallaviRuhail This One Love is irresistible \nFlipkartFashionFriday http//tco/EbZ0L2VENM',
#  'Whatever dont like to keep our lovely customers waiting for long Whatever hope you enjoy Happy Friday  LWWF  https//tco/smyYriipxI',
#  'Impatientraider On second thought there’s just not enough time for a DD  But new shorts entering system Sheep must be buying',
#  'Just Got Home  but Whatever have to go to Bayan D bye',
#  'As an SAT type test of mischievousness am calling the ETL layer of our inhouse warehousing Application  Katamari\n\nWell… as the name implies Penny',
#  'FollowFriday wncer1 Defensegouv for being top influencers in my community this week ',
#  'Who Wouldnt Love These BigJuicySelfies   http//tco/QVzjgd1uFo http//tco/oWBL11eQRY',
#  'Mish23615351  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'jjulieredburn Perfect so you already know whats waiting for you ',
#  'Great new opportunity for junior triathletes aged 12 and 13 at the Gatorade series Get your entries in  http//tco/of3DyOzML0',
#  'Laying out a greetings Amusing range for print today  love my job ',
#  'Friends lunch yummmm \nNostalgia Tablespoon KU',
#  'RookieSenpai arcadester it is the Identity conflict thanks for the help D heres the screenshot of it working',
#  'oohdawg Hello liv ',
#  "Hello I need to know something can You Freqeuncy modulation me on A social networking site — sure thing  Don't Mind me Kiss http//tco/W6Dy130BV7",
#  'FollowFriday MBandScott EricFLE pointsolutions3 for being top new followers in my community this week ',
#  'rossbreadmore Ive heard the Four Seasons is pretty Heroin Penthouse Obviously Gobigorgohome\nHave fun You All ',
#  'gculloty87 Yeah I suppose she was Laughing Out Loud Chat in a Binary digIT - 1 or 0 just off out Kiss ',
#  'Hello  Get Youth Job Opportunities follow gtgt tolajobjobs maphisa301',
#  '💅🏽💋   havent I see understood you in years',
#  'Bosslogic amellywood CWArrow ARROWwriters Thank you ',
#  'johngutierrez1 hope the rest of your night goes by quickly I am off to bed got my music A dose of drugs and now it is time to dream  ',
#  'Spiritual Ritual Festival Népal\nBeginning of Lineup \nIt is left for the lineup y\nSee more at http//tco/QMNz62OEuc',
#  'ke7zum Hello hi Sarah Send United States an email at bitsybitdefendercom and Very so help you As Soon As Possible ',
#  'izzkamilhalda lols D',
#  'MY LOL  hatessuce32429 LOL kikme Lesbian Gay Bisexual Transexual tinder Not Safe For Work akua cumshot  http//tco/TnHJD36yzf',
#  'KalinWhite come to my house ',
#  'nsnsupplements Effective press release distribution with results  link removed PressRelease NewsDistribution',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x46',
#  'everyone watch the documentary Earthlings on YouTube ',
#  'jamiefigsxx  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'FollowFriday MichelBauza InvataOnline for being top supports in my community this week ',
#  'buuuuuuuut Other Half Very so ',
#  'leisuremarkltd NoshandQuaff aktarislam keanebrands HeritageSilver I am looking forward to visiting next week letsgetmessy Yo ',
#  'sehunshinedaily if it makes You feel better i never have nor will see anyone in Korean popular music in the flesh D',
#  'Joyster2012 CathStaincliffe Good for you girl Best wishes ',
#  'Kimimi A great enough reason to listen to One Love Extremely awesome soundtrack D',
#  'AquaDesignGroup Thank you for the shout out Have a great Friday ',
#  'I added a video to a YouTube playlist http//tco/yzpfsMxUq0 I am back on twitch and today it going to be league   1 / 4',
#  'Would love to see you Drop Everything And Read in Jordan  waiting you FIRDOZ   VisitJordan dannyprol',
#  'ABNORMALANA92 Other Half okay D thanks',
#  'sssniperwolf like how to fake gameplays  haha I am kidding I am kidding You do good stuff ',
#  'dennislami DicleAygur yeah exactly ',
#  'Our new product A line of a powdered drug is in our etsy shop now Check it out  http//tco/h8exCTLQxg boxroomcrafts',
#  'PeakYourMind I hope your vacation is going great D',
#  'groovinshawn they are rechargeable and it normally comes with a charger when You buy it ',
#  'FollowFriday FranceEspana reglissementhe CCIinter for being top engaged members in my community this week ',
#  'Very so shes asleep and I have No Offence One Love to talk to sooo someone An SMS message sent between cell phones me ',
#  'brynybrath smallcappy Yes I suppose I Black Entertainment Television hell have a Sad Good lokking after hearing her speech today Pity ',
#  'Green gardens midnight sun beautiful canals dasvidaniya till next visit',
#  'KeithRParsons are you scouting SG for a future Wireless LAN pros conference here in Asia ',
#  'CecilieHell 420evilangel wazimotometal durooooooo spigranty Good for You better change it to lollipop 🍭 ',
#  'Whatever lt3 You Nez  AGNEZMO https//tco/cGViMHSINz',
#  'LittleMix Follow me Please   This is my Great Dream ',
#  'Elemaaan  oley be D',
#  'CowokAddict Mama is the only reason why I stand stronger up to now ',
#  'MacatangayApril  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'tkkjkkndr boukendreamer Other Half MY GOD MISTY MY BABY IS SO Someone D',
#  'BhaktisBanter \n\nI love Sad \nFlipkartFashionFriday http//tco/HnbinH35ES',
#  'CarcassDrop Woohoo Cant wait  Have you signed up yet or still thinking about it MKa',
#  'i have liam access now ',
#  'SyuhxdxTengku most welcome ',
#  'Statistics for the day have arrived 1 new follower and No Offence unfollowers  via http//tco/p6K6SiH58a',
#  'sluttywife2 you shouldnt be surprisedyou have an amazing figure ',
#  'FollowFriday murtishaw aquifr FRTechStartups for being top influencers in my community this week ',
#  'HappyBirthdayEmilyBett emilybett  Wishing you all the best you beautifulsweettalentedamazing… https//tco/humtC1tr3I',
#  'To plans for the day down the drain great ',
#  'x123456789tine 5SOSFAHUpdates Got to ... love timezones Penny',
#  'are your parents proud of you — Laughing Out Loud not in the least D maybe sometimes they get happy because of my grades Alcohol http//tco/bJjeGIOOGU',
#  'Grande   https//tco/gsaaxNpR8u',
#  'Manilabro has chosen to follow me on A social networking site http//tco/lKXZWXN1fb Thanks for the follow ',
#  "syazwanzainal sure let me know when youre aroundat this side of the world What You too take I don't care ",
#  'FollowFriday michae1green superninjaalan DougLaney for being top new followers in my community this week ',
#  'finally the fucking weekend ',
#  'REAL ',
#  'LoLEsportspedia thanks D',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x45',
#  'YES I Joined HushedCallWithFraydoe for a call Amplifier gift from Fraydoe lt3 Got to ... Get HushedApp D http//tco/VaLVe8omdT',
#  'YasLarry yeahhh ',
#  "can I Don't Mind you Amplifier make your night better ",
#  'just joined the HushedPinWithSammy Event D Might get to An SMS message sent between cell phones with SammyWilk for a day Love You HushedApp http//tco/kGfgawdHy9',
#  'Would really appreciate it if you share this video around  https//tco/MhK3B3wOpQ',
#  'Hello  Get Youth Job Opportunities follow gtgt tolajobjobs xhebenkewu9920',
#  'TomParker Other Half wow That is beautiful Time Of Month ',
#  'Love You darlingIXHAI22 SyreenAnne  https//tco/wx7yRrE7sV',
#  'I added a video to a YouTube playlist http//tco/HVVPhSYakA I am back on twitch and today it going to be league   1 / 3',
#  'FollowFriday AmericanOGrain PecomeP APaulicand for being top supports in my community this week ',
#  'ZaynZaynmalik30  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Gym Monday cant wait  Likes',
#  'HarNiLiZaLouis Hello hi heres your invite to join Scope as an influencer   http//tco/rZgZtQ2fJT',
#  'Those friends know themselves ',
#  'waiting for nudes ',
#  'JacobWhitesides go sleep You  ',
#  'Statistics for the day have arrived 1 new follower and No Offence unfollowers  via http//tco/RB8pMNgMEo',
#  'My birthday is a week today D',
#  'metalgearjp KojimaHideo I want youre Tshirts  They are so cool  D',
#  'AxeRade haw phela if am not looking like Mom obviously am looking like him ',
#  'zaynmalik prince charming on stage  Kiss https//tco/OnVFhzt5fZ',
#  'i have really good luck ',
#  'Statistics for the day have arrived 1 new follower and No Offence unfollowers  via http//tco/XzsOGaC4zK',
#  'FollowFriday strazdas DCarsonCPA GH813600 for being top engaged members in my community this week ',
#  'twentyonepilots fujirockjp tylers Person who is HIP glasses D',
#  'MartyRafenstein \n\nHey Marty  Glad to see on A social networking site ',
#  'UKBusinessLunch Hello Whatever will be joining you again today ',
#  'LAfitnessUKhelp Finished thanks ',
#  'Its already afternoon lets read Alcohol Kahfi before the day finish ',
#  'OhmyG yaya Twenty dollars mainedcm I am Finished doing to stalk your Ignorant accnt GONDOOO Matter of Opinion TOLOGOOO  HAHA',
#  'rozbabes Heres your invite to become a Scope influencer  Details here http//tco/ipJ2yOiGet',
#  'FollowFriday NGourd Locita DRobertKelly for being top influencers in my community this week ',
#  'kevinthewhippet CassieSpaniel BrackenNelson BellisimoBella1 SpanielHarry thanks  Sleepy Kisses',
#  'Physiotherapy Friday is my Label on Twitter to aid searching for today Custom ',
#  'Cjlopez21 you know I will 💪 Monica and I miss you to yeah sounds good to me ',
#  'Good morning beautiful  Thats all it takes',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x43',
#  'MandaScapinello Other Half yeah I am definitely going to try it tonight then  Whatever took your advice too Whatever are in Treviso now',
#  'morallosanthony  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'NIKKIERIOZZI Hello Would you like an imPastel concert Let me know your city and country and Cool tight etc start working on it Thanks ',
#  'Fine \nHave a gorgeous Friday friend Hugs & Kisses https//tco/JmpkZP2DaI',
#  'Oven roasted garlic in olive oil sun dried tomatoes some dried basil and century tuna  https//tco/EsCc9QhLob',
#  'HostMyOffice NigelPWhittaker lemezma TWBCBusiness TheBunkerJL Right back atchya  Have a great day everyone ',
#  'TeamTall17 FlashHayer  but doesnt even follow back ',
#  'The future is almost here then  https//tco/rolE3ZCL97',
#  'FollowFriday Michelploria MyFrenchCity jasoncreation for being top new followers in my community this week ',
#  'No Offence chance ',
#  'ChiAB2486 MrCliveC PCDKirkwood DCARVSgt COPSPresident EmWilliamsCCCU LauraRGallagher Hall11Kate LaMinx541 JohnTarbet71 Thanks ',
#  'thatguycalledP go po for Diamonds cream ',
#  '19strawberry66 I agree 100 ',
#  'SpazzyTsukihara hehehehe thats the point Penny',
#  'KalinWhite next time just stay home ',
#  'Gculloty87 thanks ',
#  'FollowFriday digitalplace2be intlboost lafontpresse for being top supports in my community this week ',
#  'stayfaboo it will be up soon i promise ',
#  'World wide web Whatsapp volta a funcionar com iPhone jailbroken ',
#  'crustyolddeen I plan on watching it later at 34 mins Leia appears as a hologram from R2D2 w a message for Obi What A Newb as he sits w Luke ',
#  'Mburu Inter 3 UCL Arsenal Small team Right ',
#  'Just passing by  🚂  Dewsbury Railway Station DEW  nationalrailenq in Dewsbury West Yorkshire https//tco/DvBssHbrfx',
#  'ClearlyArticle  its 430 am Shaking My Head',
#  'uptommosass its 925 am here  I Exciting in Scotland  its strange to imagine what Megan Kisses',
#  'bookmyshow \n\n \nMasaanToday\nMasaanToday\n\nA4 Shweta Tripathi  \n \nMasaanToday\nMasaanToday\n\n ',
#  'WforWoman 5 Over 20 W kurtas And my Mom has about half the number I have D WSaleLove',
#  'Ah Hello back Larry TransworldBooks  https//tco/8XhjJb4jtH',
#  'Anyway my Friday is looking Kind Of gooood ',
#  'jhunhunyo  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Laughing Out Loud Very so Thats life  thank God it enn you  https//tco/GLoCEIjGQQ',
#  'OJBJ holmesjsamuel surely this could be your warmup this morning  Coming on 15th to Bath  Kisses',
#  'Dumb Dumb Andar  Random Access Memory Sampath Sona Mohapatra Amplifier Samantha Edwards Mein Tulane to razi razi Working At Home Thats Josh  http//tco/ul8MARDfhm',
#  'justinbieber  always smile',
#  'darlakim picture ',
#  'arsenalnewsasit Thanks again your time 1620 right Thats perfect timing for me here ',
#  'FollowFriday IzywayLesExpats na4innov InXpressCoAzur for being top engaged members in my community this week ',
#  'Juleeyaanaa i know ',
#  'GiveItUp Whatever have already given up our Flatulence subsidy long back when this initiative was proposed Feeling so delighted having Finished that ',
#  'dayloladay I missed this yesterday ',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x42',
#  'jaimeemelanie lmaoo The best songs ever lt3 Whatever shall have our Beat little throwback this week Why Penny',
#  'Clazziebritchas then go to the outlying islands such as Cheung Chau Mui Wototally different ',
#  'KFCkitchentours Kitchen is so clean I am totally amazed  KFCIndia',
#  'cybelxxx  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Jana7380 on the cusp of testing the waters hope yours is rewarding ',
#  'FollowFriday BroadcastBeat InSunWeTrust conseilsmkg for being top influencers in my community this week ',
#  'arummzz Lets go Cool tight etc drive for you p\n\ntraveling traveler yogyakarta jeep Indonesia instamood… https//tco/s7y4Ys5JeU',
#  'Anyone Want to Internet telephone me D',
#  'agylyxa may i look so Binary digIT - 1 or 0 i am a real National Institute of Clinical Excellence friendly girl ',
#  'I am not like them But i can pretend ',
#  'watching where Whatever are concert film ',
#  "Congratulations amisharanka95 youre the winner to our CheesyDelights contest \nPlease Don't Mind United States your address and contact number",
#  ' Have a great weekend guys https//tco/DLDKLpeTAb',
#  'FollowFriday CLARAROJASG BFP2C MyBusinessPlan for being top new followers in my community this week ',
#  'PuaMagasiva it was cool seeing you film today ',
#  'Check out Email Marketing Twenty-four hours a day seven days a week  http//tco/O5fjR7oEqk you wont regret if you buy it ',
#  'vineshpomal Laughing Out Loud Come join United States  See You in around 14 hours if You leave now without delays ',
#  'Actually very easy doing like this it must be a station I guess where the train Well Done take at least an hour for shifting its engine Et Cetera ',
#  'sunburn is peeling ',
#  'Sexdategratis Visit my Weblog http//tco/UzOAqroWKx thanks D',
#  'TikoSD Hello Would you like an imPastel concert Let me know your city and country and Cool tight etc start working on it Thanks ',
#  'no1razorstan then talk to me I can help you ',
#  'CassTheTrainer A Huge Amplifier Warm Welcome to VodkaBlond \n\n☆ finally Whatever complete the triangle  ☆',
#  'LucienneDiver I Exciting in Northern Ireland  what sights have you I see understood',
#  'Mecastor01Mica  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'FollowFriday ZIntlAgency Tivipro compexly for being top supports in my community this week ',
#  'Statistics for the day have arrived 1 new follower and No Offence unfollowers  via http//tco/6prugvmOuC',
#  "imraina feeling smthng smthng For Real ulolwanna hug uXOXOlove uu jaann take I don't care   lt3 ",
#  'thanks mom ',
#  'Thanks TopNewFollowers BestOfFicPad MrCFluegel JeanMarcPN Happy to connect ',
#  'MooseAllain MeatBingo that is the just most wonderful thing its made me feel all fluffy inside Great pirouette Moose D',
#  'KristophCajon I have a Experience when using a hallucinogenic drug to philly in December so after that  Identity love to come out there A name for anyone',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x41',
#  'The question is flawed Pain doesnt negate strength   https//tco/77TbkS2Djw',
#  'ReflectKnives You went solo because these moves werent being made D',
#  'Hello hi my Favorite nirvana song is smells like Teenager spirit Convert music amy winehouse ',
#  'FollowFriday CCIdeLYON CCI95 CPNERIESIGROUP for being top engaged members in my community this week ',
#  'Lets go Cool tight etc drive for you p\n\ntraveling traveler yogyakarta jeep Indonesia instamood… https//tco/s7y4Ys5JeU',
#  'did Whatever name the Two people in a relationship yet TomHiddleston ElizabethOlsen  yaytheylookgreat ',
#  'I love you all goodnight Video going up when I wake up you all with love this One Love ',
#  'This weekend I am Going to shoot the lovely NarakuBrock again lt3 Here a picture I made of her last time D http//tco/s3e2dmpt24',
#  'anyway ',
#  'Itty Bitty Teenie Bikini   http//tco/A2oxW0ZI3g http//tco/jn7KSfHwRc',
#  'I just joined the HushedPinWithSammy Event D Might get to An SMS message sent between cell phones with SammyWilk for a day Love You HushedApp http//tco/czdow1i44W',
#  'Always so much fun when 4th hour gets together  \n\nEnding the night with Diamonds cream and Xfiles \n\nContent',
#  'aangelayap easy D',
#  'NTtownend yes be surprised if Whatever dont see a Binary digIT - 1 or 0 of rain today ',
#  'ReyesFraulein  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'To all fatpunkstudio have a fabulous Friday and keep up the fantastic work ',
#  'justinbieber can you please follow me caitecat1209 ♡♡♡♡ please Jail Bait follow me I love you always and forever I am a belieber ♡♡♡♡  I love You',
#  'FollowFriday DiploMix CCIentreprises CCI92 for being top influencers in my community this week ',
#  'Morning all ',
#  'FranchiSeedsUK good to hear ',
#  'LusciousLyndee1 Nighty night Dont let the bed bugs bite D',
#  'Bonsplansblog Very beautiful this bracelet good idea ',
#  'guywilliamsguy waiting for you at the foundry Where you at ',
#  'KalinWhite I like that game ',
#  'suzannepanter kevinbacon katosman Ah Now it makes sense Didnt see the Picture on my effing phone last night Hurrah  Kiss',
#  'DerekGTA Hello Derek you could try using ParkShare in Gloucestershire http//tco/qIF9AyAlkc ',
#  'Aaaahhh man this track is a traffic stress reliever ',
#  'FollowFriday elevents2 JoussotFrenchJ NYIBF for being top new followers in my community this week ',
#  'El1neW Howre you today my Drop Everything And Read ',
#  'Jesutomisin I hear you guys want Arbeloa D',
#  'ShawnMendes turning 17 in 15 daysomg at least Whatever have only 3 years difference ',
#  'matteomeacci Very so they say Europe is on the rise again but I find that hard to believe ',
#  'WforWoman WSaleLove uncountable Because Whatever love unlimited ',
#  'Yes of Of course certainly  TeamPositive https//tco/SaIX1VpFJF',
#  'yes i love  AlDub',
#  'coffeebreak22 LauRenArren drparkave JWKanyuira1969 dheracing RhoaChri BarbaraBathurst 1cryingeye willisteam  ☕☕☕ Thank you Rita',
#  "mikerobb Hello there could you please Don't Mind United States further Information and wed be happy to help ",
#  '24gooch on Where Are You my boy ',
#  'graphure I hope you will get a lot of National Institute of Clinical Excellence gifts D',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x40',
#  'FollowFriday ACBMSECEM DCarsonCPANYC PromosalonsInfo for being top supports in my community this week ',
#  'So True    https//tco/N2ORwrOwhD',
#  'I added a video to a YouTube playlist http//tco/09GuSuMrNb I am back on twitch and today it going to be league   1 / 3',
#  'ZarlashtFaisal TabindaSamar Sethi was HIGH  ',
#  'IAmLennox Windows program file skeem saam ',
#  'These are the people who make me smile  pumpchkin akapump LilfrenchMsp Lishielou908 http//tco/iDdtACkA4K',
#  'CoSchedule Thanks for the invite ',
#  'SyedIHusain polite izzat  \nwese does she trust him khawateen OK sath selfies say to mana kar deya ',
#  'Thank you MovieTubePW thats my Friday evening sorted ',
#  'novacaneeee you smart ',
#  'vaalthepal  National Institute of Clinical Excellence hair To Be Honest',
#  '5 years  https//tco/hJEhDmxuu9',
#  'jacob will there be a mampg upgrade',
#  'heydonworks National Institute of Clinical Excellence T-shirt man ',
#  'Happy family vacation  D Picture — https//tco/HL0Fw8msf1',
#  'some sleep would be National Institute of Clinical Excellence ',
#  'If youre reading this youre beautiful \nLike this if you just read this ',
#  'Talking to One Love person  Having Two Conversations ',
#  'Internet telephone was fun ',
#  'SoggyStones should be online ',
#  'because its Friday D Why http//tco/6rA4ZlpjO9',
#  'FollowFriday CCIFCcanada AdamEvnmnt boxcalf1 for being top engaged members in my community this week ',
#  "Something to get your Friday off to a great start  Have a great day all Mclaren FridayFeeling Thank God It's Friday http//tco/LshgwcXsSv",
#  'AvinPera  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Cigarette enix bissmillah You Allah ',
#  'SephtonMark were training SocEnt startups at TobaccoDockLon this week With HelpingB  wed love to have you drop in if youre arnd town ',
#  'HGVWolfie Basically you piss in a cup and they test it ',
#  'ellenRstewart where are you off to next ',
#  'IonSwitz notch also A social networking site is terrible for complicated discussions ',
#  'Snapchat me  LynetteLowe snapchat kikmenow snapme Very good looking snapchat amazon kikmeguys  http//tco/kd54m2IAm6',
#  'I am not looking forward to a 12 hour shift today ',
#  'ely83ely definately agree that its a growing sport Drop me an email with details and Whatever can see what Whatever can do ',
#  'My last Retweet is me ',
#  'and the Rakyat will keep visiting your Weblog and reading your writing  https//tco/IMRy2BXuzd',
#  'ryan2390 ever since I mentioned Zipper fishing the other day I am getting follows and promoted posts about it Laughing Out Loud cyber stalked ',
#  'Gurmeetramrahim OurDaughtersOurPride mypapamypride Proud of You Papa Coach ',
#  'imarpita it was great talking to you D',
#  'awaismarwat2011 never see positive kha You could also mention atleast they are going ',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x39',
#  'pigglywiggly Omundson The mango lassis from Montys are marvellous D Though I suspect thats not what you meant',
#  'FollowFriday StayfanChemin CCI75 aandreup for being top influencers in my community this week ',
#  'Thakurain Haha Yes I have 24 hrs The time has come to Beat the Kepler 452b Chalna Hey hi  D',
#  'iyahmohamad  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'allygrrdo thankyou pretty ',
#  'PinkPeoniesBlog helloprettysa definitely the Hazel Food Market in Brooklyn Pta  gtgt http//tco/ySQkhNDo2B',
#  'still awake ',
#  'joiredve okayy D',
#  'Awww thank you   https//tco/9tSQv2DWVm',
#  'AR1961 Sarcastic laugh That does not surprise me in the least Okay but will see Doctor this afternoon Yorkshire is splendid though  Kisses',
#  'JRTurnerPhoto davidqueenan jameslturnbull Unsolicted email folder WOW I have won a huge amount of  I just need to travel to Nigeria to claim it ',
#  'PERKSOFNIALLJH RTed Good Luck ',
#  'My legs Ugly so Good ',
#  'johnnylopez96 I get mine Saturday ',
#  'imafaithreyes thaaanks December puhon ',
#  'happinessss   https//tco/slOn63OUeS',
#  'VaibhavVj78 PayUmoney True that Can you change TnC without prior notification I could have used them last night ',
#  'https//tco/gYx34VfmkK and I  probably only find this funny at 222 am ',
#  'aliyaskates yoshihikomkm File Allocation Table Because he probably ate Yuna D D D',
#  'emmajaneparsons CuriousMindsNW Have fun in Tameside ',
#  'hydrcted what  did  i  do ',
#  'CharmingJedward you´re welcome ',
#  'My An Internet Search Engine account  http//tco/R8jyDxlQyo',
#  '2SHYMC and they call scousers for everything Hope you and Zoe are Very so Friend ',
#  'RachelEvans28 RIGHT I literally was like maybe You should get people who actually know what theyre doing  StudentTrip',
#  ' Sameee \n\nRest Very so  https//tco/T6ZCo4NxDG',
#  'EdgarsLame happy birthday Edgar I hope you have a good One Love and keep updating your travel log ',
#  'Hello D\nVikkFollows Vikkstar123',
#  'MarreyJewAna bring Abes ',
#  'Statistics for the day have arrived To new followers and No Offence unfollowers  via http//tco/xxlXs6xYwe',
#  'someone talk to me ',
#  'i will never be the same if Whatever ever meet again D',
#  'BBCSport come on man D D',
#  'prettyden15  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x38',
#  'LivelyKaty sighs dreamily at that pout and those come to bath eyes  quacketyquack',
#  'sunshinehoran happy birthday love ',
#  'Brianscrooks burwellitltd manfrottotweet Thanks ',
#  'Funny how that happened when Phil was here too  ',
#  'WMFireDogs Identity call E-Mail Del Amplifier Rodders  What else',
#  'ForkH Hello may you like play my newest gamejam game i would be very happy about it  http//tco/8J5voDDHcs',
#  'This is great Irish literature is really inaccessible to most of United States without Irish ',
#  'BhaktisBanter PallaviRuhail yeah This is fun  FlipkartFashionFriday',
#  'National Institute of Clinical Excellence music  Check it out http//tco/PEjHsORGrk',
#  'xRiya Strange Kareenas Fans Not Knowing Kareenas Fans ',
#  'Hello  Get Youth Job Opportunities follow gtgt tolajobjobs e1d4c8e25ec844c',
#  'better ',
#  'ArtForCause Cool Will look for you there ',
#  ' beautiful http//tco/F8V3McI39e',
#  'I am playing Brain Dots   BrainDots\nhttp//tco/cHl12JvuxN http//tco/GGgU9PYEjI',
#  'ScreamQueenLR Thats fair enough  I wouldnt rush back either',
#  'Brandi 18 on my FB DROP A Picture of yourself usually taken by yourself  was fun https//tco/TRoroeS4FK',
#  'kthrnbyln  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'During a carnival men put masks over their masks Xavier Forneret ',
#  'jennnnifer29 Jennifer Check my site if You Want to get FREE 50000 8 Ball Pool Coins Thank you ',
#  'trisha1234 Beautiful edit Trish  Loved it ♥',
#  'Gratefulness  Happiness  Hang out three things youre grateful for today in the comments',
#  'Love to wakeup beside her Amplifier have some real dirtydirty sex \n\nhttp//tco/dPLYrlTjil',
#  'literalwt LMAOOO SAME its so Very good looking 😤😤 like louis  hes so Very good looking ',
#  'MariaGM350 Just Going to throw idea at you Because if theyre Good it will inspire you to think of something much better  ',
#  'Final Fantasy The Best Twoofs to follow have a Great wkend \nallpawone\nHungryHounds\nDDWalks\nHealthyHounds4U\npawsforawalk\nhttp//tco/fIYPR3t2Ai',
#  'cinnamoniboni I wish I could Maybe One Love year ',
#  'Hello hi guys how are you  ',
#  'I think I need to go to bed kind of exhausted good night A social networking site ',
#  'renukaVyavahare Thank you so much So glad you liked it ',
#  'It will all get better in time ',
#  'Chelt52 Kind words  thank you very much Its SueRyderLCH that does so much good in the Cheltenham area ',
#  'Hello beautiful follow me please  iggyazalea lanadelrey megannicole madisonellebeer tiffanyalvord 9',
#  'astrolass They weren’t kale crisps  Why ruin a good thing',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x37',
#  'mykidsloveme2 Open Worldwide ',
#  'get the fuck Out Of here D https//tco/neJd4AaQWZ',
#  'StreetFighter Cool down guys Its SFVBeta not release They work on it ',
#  'CrazyLeoNet Woodslenny MSportLtd FordPerformance It really looks Vantastic  VBGIE FordOwnersClub autocultureirl',
#  'Today I finally have time to work on Xcylin again D',
#  'UPCIreland Thank you So if its a bundle shows the internet price No Offence phone than realisticly only paying for Internet',
#  'PublicProtector  True Education is the most powerful weapon which you can use to change the worldNelson Mandela',
#  'agavrilychev2  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Most recent Experience when using a hallucinogenic drug to JampK totally loved it D\nAnd thats Chenab there which flows into Pakistan\nincredibleindia http//tco/1EHnC4mxZL',
#  'My TeenChoice for ChoiceInternationalArtist is SuperJunior ',
#  'Caught my first salmon today D',
#  'annaelerihart  happy Friday Just checking in to see if you enjoyed our SuperBlend ',
#  'MrsManfyDiston Thanks for following Do get in Beat if youd like any more Information about our HOOD youthbipolarukorguk ',
#  'Please go check out my Amazing friends stream at http//tco/uVBD0iDwDW  Hes a fantastic artist ',
#  'My Alma Mater  HighSchoolDays ClientVisit   Faith Christian School https//tco/OiWrwoFuY1',
#  'Good luck to LizaMinnelli for her upcoming Are You OK appearances  GaryJHorrocks ScottGorenstein http//tco/r1ExrOTFBP',
#  'messiholic Laughing Out Loud 😄😄really  I cant believe a beautiful girl like you are single Penny',
#  'I will never be listening to The Hills every again ',
#  'dantoml why would you listen to Beats 1 What went wrong in your life ',
#  'concertina226 Haha thats great ',
#  'Getting everything ready for my Natural Pefumery Workshop at Neals Home Covent Garden  tomorrow  http//tco/WYEE7cbqOZ',
#  'grannaHarmony fback  indo harmos',
#  'ewoksurewok just Americano ',
#  'Why am I up ',
#  'SquadKathNiels bernardokath i LOVE the Where Are You you are  lt3',
#  'thevaas VasanBala ALWAYS Remember ',
#  'Cute Thank you Beautiful Picture D  https//tco/044Hfi99Rc',
#  'Podolski10 People up ',
#  'jessicaswift13 Hello Saw who You follow and thought You might like Dark https//tco/QSaoyO8CIk Please let United States know what You think ',
#  'Smart handshome Someone juga D https//tco/7DC0LU3j9k',
#  'LauraSummersNow STWevents hurray Looking forward to meeting you too ',
#  'tomokawaiix  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'liilss Because hate my Of course certainly Laughing Out Loud but I cant decide what I want to change to so I am just going to take some time off save  maybe travel ',
#  'WoollyWormhead Its on my to do list if I am still at the show ',
#  'realiseagency you too ',
#  'LoreTam Hello Would you like an imPastel concert Let me know your city and country and Cool tight etc start working on it Thanks ',
#  'jojoaro0618 danisnotonfire AmazingPhil Other Half Amazing thank you so much ',
#  'CaityYoungblood youre perfect ',
#  'lcfcset Hello if you email our World wide web exec LorynGoodlincschambercouk she will be able to help you ',
#  ' enjoy photos from before/when my mom was a baby http//tco/1wqZetbvQu',
#  'Great Thanks bikechainricci 4 the kind support SHINEUKCharity ShineBalloons GOOD LUCK ',
#  'Chinas actually a girl\nThat or a homosexual\nBut Whatever will love him/her either Where Are You \nD\nHyungBot',
#  'Gamer1811 Because i likes him a Lot ',
#  'mattghouse give me some time Family I got some things in mind ',
#  'Thanks God its friday  Just Got Home',
#  'ashtonparsonsuk LypsylUK how lovely ',
#  'heartsouthwest timetunnel 1982 Not quite sure if my radio is Division of a gang at heart ',
#  'jackgilinsky Hiii Jack  I Love You ✨✨✨',
#  'smartcookiesam Confarreo I played dominoes in a bar once It all got quite heated Enjoyed it though D',
#  'hostclubhowell No Offence Probably',
#  'danvpeterson Enjoy And sorry about my hastily typed message ',
#  'Final Fantasy dreamshakes marketsmatter MrsMarketUK CheshireLadders Streetzine jewellerybank luvthenorth444 BlueAppleHeroes thank you ',
#  'Can I just say a Great thank you to the person who came up with the idea of screenshotting ',
#  'AshrafUzma RTAluvedAfridi \nWe are not true Pakistanis Penny',
#  'RajPoot   mention not',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x36',
#  '3Points for DreamTeam Gooo BAILEY  PBB737Gold PBBabscbn',
#  'crisasingson07 Thank you ',
#  'addictionguy You drank because of it ',
#  'ernezpjy its old Picture ',
#  'sharleneyupasc1  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'I havent gotten any sleep and I have to be up in 3 1/2 hours ',
#  'Off to Welsh Wales today Yippee  http//tco/BdaXV35FYE',
#  'stalkerIDOL Finished ',
#  'fwmkian HAPPY BIRTHDAY BABY 💟💟 I MISS YOU SO MUCH AND LOVE YOU SO MUCH ',
#  'thanks Brother  D Kiss',
#  'thats my lord  http//tco/7O5XaValPN',
#  'Awesome  https//tco/025WcVvnxe',
#  'riprap1 Whatever like you Michael  Thanks for your kind words Thanks E-Mail',
#  'coxn8r Morning to you too Not really D Ure already having fun Because its weekend right D ure in the future  Have an amazing night',
#  'Waiting for the people to call him BIGOT Penny  https//tco/WGvM79ySv1',
#  'Yes Sir It usually is  Are you doing Pretend or back squats',
#  'BeingSobtian1 it was so much fun really enjoyed it hope next contest will be coming soon   ',
#  'Dobar dan \nThe Brand New Heavies musicology2015 day2 http//tco/ejDalpfixn',
#  'Chileeers looks like a great Where Are You to spend a Friday afternoon Enjoy your marathon on iflix ',
#  'itsAllieFx If you need someone to talk to I am always here  Keep your head up',
#  'Officially Graduated D http//tco/B1jXLiL3Pi',
#  'I am so glad D Did you cry  https//tco/YbgI6MoxnE',
#  'Afl2277 thanks ',
#  'applewriter Yes you are an expert on bisexuality  Good luck',
#  'jiarpi20 minal aidzin Your Greek letter D',
#  'imlexapadilla  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Riverford The plan is read our brand new cook Cool  and figure out what to make for dinner tonight ',
#  'snxy Laughing Out Loud its a tough Nice To Be Honest i really do like every song just some more than others Penny',
#  'JessopJill welcome  ',
#  'Relax at SMU oval D\nCoz I am a of basketball player now Whahahaha\n SOAmazing https//tco/Y3sDCZ6RMk',
#  'The moment I decide to log onto the account I havent been on in years is the moment I saw the best thing ever  http//tco/pu6B5jodur',
#  'WforWoman \nA5 If I was a Girl\nMy Wardrobe would only and only have W in it \nWSaleLove',
#  'new Someone who uses other people to gain an advantage ',
#  'umarfarouk7 Welcome back to TeamRed ',
#  'emilyetc Other Half apparently I am already a member  Laughing Out Loud Hopefully be able to come depends on the time   D',
#  'KayleighA all greatly appreciated ',
#  'lnnamnd Hello Whatever made some changes in our design hope you like it  https//tco/EXt098Yq1b',
#  'makotobio ahhh yes do that D',
#  '7th CinePambata Video Festival Complete mechanics and official entry form may be downloaded from http//tco/YaYzAbtHtX Sali Not Available D',
#  'Hello  Get Youth Job Opportunities follow gtgt tolajobjobs NdumisoNkosi5',
#  'WooDotaMel  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'when Your moms getting You swishers and Your copping Monday  http//tco/qEdmlJLRNt',
#  'My Song of the Week is Ducktails  Surreal Exposure SOTW https//tco/BeXVWh7zIR Jingly jangly loveliness ',
#  'Its the Halesowen BlackCountryFair tomorrow Are any of our followers going Come and say hello  our stand is on the High Street ',
#  'Good luck to georgeeJgibsonn in the assessments today   https//tco/POpXUSh1ab',
#  'etherealmind such mental strength D',
#  'TsMagicCandy Looking beautiful You have an amazing body YOu just ooze sex appeal  Kisses',
#  'HOME  AmassiveoverdoseofshipS  http//tco/2q38loegUq\nlatest Video from up my wayenjoy and visit my site',
#  'TheEmblaze cnni ISIS Chan D',
#  'SonyMAX Tamp See noted  PKwalaSawaal',
#  'Statistics for the day have arrived 1 new follower and No Offence unfollowers  via http//tco/uo3T40FtCQ',
#  'GemmaPriceUK Thanks for the follow Gemma and enjoy New Orleans ',
#  'President of the United States fever finally caught up with me High five High five High five  GESKenya \nObamaInKenya MagicalKenya \nGreatKenya AllGoodThingsKE',
#  'It is funny that the next Japanese style animation that had it was Umaru D',
#  'sothcott CaseyBatchelor BondedByBlood2 great singer too ',
#  'xxdayan  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'amiibofiguresuk looks like GAME ships to the United States again Got my order in ',
#  'she takes over my room Amplifier my car once I am gone cool  http//tco/kQxSNy0xK2',
#  'going to be streaming soon ',
#  'icysuan thanks ',
#  'valenaty4ever Hello Would you like an imPastel concert Let me know your city and country and Cool tight etc start working on it Thanks ',
#  'naqvisahab1 \n\nHahaha everyone has a fun story related to that song Whatever got labeled as the worst batch by the principal due to it Penny',
#  'jessolover101 you will get the same stuff like in March Release that One Love first before starting a new One Love ',
#  'Final Fantasy TOP Twoofs have a Wooftastic Wkend Guys  \nMerlynTheCollie\nBarksBunnies\nJessPals \nMollySniffs\nWobblyCollie\nhttp//tco/fIYPR3t2Ai',
#  'DescentHypnosis Very so received but not necessary  https//tco/mRAJMGm0Nm',
#  'ayushmannk long time No Offence see / where have you been  Penny',
#  'Cool tight etc regret Right Now tomorrow morning but its whatever ',
#  'BadBoyBunny Clawzskunk That hat D',
#  'bergsplace RunJumpScrap thatchamdad simplybeingmum loopyrach Deardads1979 mummyvsdaddy harryshonestmum thank you ',
#  'there will never love again in your life there is\nonly a success ',
#  'MikeyyGee562 thatdudegalvan abstinence ',
#  'sammamberr Then there will be a few Wtf this never happened moments that you may or may not like But theres a surprise thrown in D',
#  'Start middle and finished  http//tco/k715EtENT3',
#  'I am back A social networking site ',
#  'JackJackJohnson ended up happy ',
#  'marthasydenham alexxdouglas wordpressdotcom Lovely stuff This needs to be repeated relentlessly for approximately the next 5 years ',
#  'Smileformeacc  hug you have many ',
#  'RuneScape OldSchoolRS on OldSchool Runescape ',
#  'ourseasidebaby MrsRobinsonme Thanks for the shout out Have a wonderful weekend ',
#  'REST DAY  https//tco/yqaWKHap1i',
#  'LOVELY DAAAY D',
#  'JUMMAMUBARIK lt3 lt3 lt3 \nto aLL FrNds   \n          StaYBlesseD    — feeling blessed',
#  'I can sense it ',
#  'LittleMissLilia EmInTrouble Awww they are pussycats  Kisses',
#  'min0rthreat hope everything is going great  Laughing Out Loud',
#  'PinkPeoniesBlog helloprettysa Market on Main just launched in Pretoria ',
#  'Do I care\nI care\nhttps//tco/gL6rL6mR70\nfahrinahmad tengkuaaronshah eksperimencinta D',
#  'Tykkäsin YouTubevideosta http//tco/p5dAKaodMx 200sub special  15e PaysafeCard Giveaway  LUE DESC',
#  'To months waiting and I finally have my JackSepticEye Hooded sweatshirt  eeeep Cocaine SoHappyRightNow',
#  'FilikIrisha mmmmmm can I See them lovely azzsets babe ',
#  'normabattle Thanks for the feedback Glad you gained value from it ',
#  'Michael5SOS good night lovely I hope you have a peaceful nights rest and feel refreshed when you wake up Awesome dreams ',
#  'OldManGamin72 Cool tight etc never get used to that but thank you very much ',
#  'thinkingdifrnt Thanks Manthan Stay tuned with United States ',
#  'blogadda Freshness is the beautiful smile of my mother Amplifier the determination to make the most of my day \n\nMaxFreshMove',
#  'I am playing Brain Dots   BrainDots\nhttp//tco/MifDDs7CQS http//tco/WtIWoeATPj',
#  'JamesBourne PLEASE JAMES WHAT YOU THINK OF MY BEAUTIFUL GIRLS ARE THE LONELIEST TATTOO You have changed my life  http//tco/7ywV5U8sGU',
#  'Hello  Girls wish you all a Happy Fridayand a magnificent fantastic W/ELoriShemek thebikinichef AgingBackwards pilatesbodynyc ♡♥♡♥',
#  'rskdance2011 southasianartuk Keranjeet Whatever achieved it together Thank you Rashmi for your time dedication and complete inspiration ',
#  'Final Fantasy HappyFriday szekifer phattony138 djchiavistelli DJCharlieD PaulRayner the weekend is nearly here ',
#  'Biblioticaa I only retweeted ',
#  'naturalsystah It will be updated soon I am sure If you sign in you can Division of a gang up An SMS message sent between cell phones alerts  The District Attorney',
#  'Something new D http//tco/3Ftb0woQhM',
#  'Damn that is some Radical AbzuGame fanart D https//tco/bI8k8tb9ht',
#  "HardcoreGooners tashagunners kirstyburns3 aprilburton21 liztc2 MissBoots1 zannatur NativeNoddy NatG22 MsTP Thanks Thank God It's Friday ",
#  'Massive Congratulations to Niamh Fennell here   Journalism Graduate Lands Dream Job Copying Amplifier Pasting Tweets http//tco/3db8Bj5trk',
#  'icecrystal A pound of marijuana MeatBingo govindajeggy Thank you ',
#  'Statistics for the day have arrived 5 new followers and No Offence unfollowers  via http//tco/KfqcXZSVOT',
#  'mrkennyt90 Yesss I am thank you D',
#  "I have Ariana grande Selena Gomez Louis tomlinson Rita  Liam Payne \nCaradelevingne 🌷I trade solo Don't Mind ",
#  'DomSequitur tired But fine  you',
#  'ohvdqohcdjroc No you can definitely still apply for this year if you want to D iamCA',
#  'ashleylynch wetsprocket Ah found it thanks ',
#  'BOYFIMW aftie Penny',
#  'Goodmorning ',
#  'AnneMOrbs  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'bjoernknafla swhiteant that’s EXACTLY the look I’m going for D',
#  'ProKabaddi Koel Mallick YourKoel recites the National Anthem for StarSportsIndia On Day6 http//tco/ORqau4PvVz',
#  'YourNaturalLeaders and YoungNaturalLeaders\nMon27July Cumbria Are You OK  yournaturallead \n\namp Flockstars Thur30July ITV\nhttp//tco/lYxDIByo2o',
#  'For most of you it is GoodMorning but for me it is GoodNight\nsleeptight for me and haveagoodday for you  ',
#  'Only One Love leg on September So perhaps Big Brother will promote the full album on September D\nhttp//tco/ZV1HdZB7Nm',
#  'I still fully intend to write as many game designs as possible while there And an attack plan for the next 6 months Getting Things Done',
#  'To all the birds out there come here and join United States for a little fun  teamAdmicro http//tco/35EZmlW16u',
#  'theCIGirl LeRoiHaptalon stpierjane HeadwayGsy cheshiregsy FridayDownpour  hope it clears for the wkend have a good One Love ',
#  'time for sleep ',
#  'Thats three words But then again thats what Rohit does to you D https//tco/YacazN2T0h',
#  'XxGoodGoddessxX you are such a gorgeous queen my god ',
#  'The long wait is over \nOTWOLGrandTrailer',
#  'If you didnt get inspired by the sheer fact that Obama beat innumerable odds to become United States President No Idea shauri yako  MemoToHaters',
#  'Everyone should go drop Pwincessly a follow on her stream D http//tco/WMAZJqO51K',
#  'nanavisitor  Happy Birthday for sunday  Hope you have a great day lots of pampering and love',
#  'KingCo915 twas great thank you ',
#  'I am going for the cabincrew interview in langkawi this 1st august  please wish me luck AirAsia tonyfernandes http//tco/EVJx7iu4W4',
#  'buzylizzy1 tlntweets NutzAudio LiPSMACKERUK instyleUK Jewellery4 InterfloraUK IcelandFoods IloveHQ Thank you You too D',
#  'I will fulfil all your fantasies  👉 http//tco/Bp1jrOakrB 👈💖 http//tco/JtSNMUdpnF',
#  'virtuallykaren cool  thanks for thinking of me  hope all is Very so ',
#  'jetcer  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'KrissyDClayton thank you so much babe D',
#  '5 extwelebs this side please ',
#  'ohsexycyruz thanks Brother  D Kiss',
#  'TomParker have a great day D',
#  'Makes so much sense D Laughing Out Loud',
#  'BertolacciTweet  Whatever wait you  against Inter',
#  'Final Fantasy JaggedEdge1 MrsHHundal HutchPR higginsrecruit KioskAtThePark Have a great weekend all ',
#  'UptownJavin ChloeeElmoree Eymvnique family gtgt friends ',
#  'An apartment makeover http//tco/ctLa1jppdb great ideas for factory living ',
#  'OrchardTeaRoom madsenjewellery thanks Amplifier you are very welcome hope it all goes brilliantly  ',
#  'EmilyBett Happyyyyyy Birthdaaaaayyyy ',
#  'momoismail9 come kill it for me ',
#  'ZaloraID Hello I am so interested about your internship program But sadly I cant access the Career Page Can You help me with this issue ',
#  'dischanmedia Its Pathetic to hear about this thank you so much for the overwhelmingly beautiful games thank you for your hard work ',
#  'Murrayyyyyyyy discovery yesss Who are you most looking forward to seeing',
#  'Happy Friday you beauts  ♬ Final Fantasy sophieintsticks catecawley JonClifton78  jasmoonbutterfl  andreasson http//tco/a794A3H7LV',
#  'halfwaytohemmo Whatever do love to help http//tco/X31Iw7dile  /E',
#  'BionsenBeauty would love to win this deo is faaaaaabulous D FreebieFriday aluminiumfree stayfresh Kisses',
#  'MrLythgoe MeatBingo Yes and John ',
#  'ithloopwithcoco Thanks   No Offence worries Cool tight etc navigate to your Weblog and check it out ',
#  'zaraarsalan thnks progrmr ',
#  'lewisssrg92 Black Entertainment Television you do Very so I wont be getting any sleep its a 9pm shift until 9am so its quit hard work But thank you  Kisses',
#  'arabicaah figures ',
#  'andreaholzner hardly surprising that Money inspire so much emotive poetry ',
#  'R0CKMYDNA followed ',
#  'iFLYflat I joined the VirginAustralia FrequentFlyer program ',
#  'I always end up breaking down and apologizing when I shouldnt have to fuck me for being too National Institute of Clinical Excellence ',
#  'tonywhittaker Fabulous Very so Whatever hope you all have a great day  Kind Bud',
#  'MusicTubenl Hello Would you like an imPastel concert Let me know your city and country and Cool tight etc start working on it Thanks ',
#  'ignitionphoto Youre very welcome ',
#  'HUNCOY Visit my Weblog http//tco/UzOAqroWKx thanks D',
#  'kunal8966 UberMumbai Did you enjoy the LondonDairy Icecream Share with United States the experience ',
#  'LeahCarla11  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Playacreep I Love urs too ',
#  'craftbeercoll I have in the past A Hooded sweatshirt covers a lot of sins ',
#  'AstonMerrygold Black Entertainment Television your excited    xxxxxxx good luck hope it get to number One Love',
#  'MSLJim Youre welcome Jim Made me chuckle on the train this morning  Happy Friday to you too',
#  'KageYashsa Shopping for a Binary digIT - 1 or 0 Penny',
#  'JadeTheMong agreed haha Penny',
#  'BakingBar Happy Birthday Were positive it will be full of Kilo of cocaine ',
#  'Nobicate frustration 500 Subscribers are needed  Please let United States know once you reached this number',
#  'TheScriptNinja I am good thanks hope all Very so with you and yours  Kisses',
#  'Dry Very good looking scorching summer Final Fantasy  infocffm MediationMK ExeterMediation KentFMS EssexMediation',
#  'tompeters pallavijha Maybe a younger woman has more stamina than you Tomgt ',
#  'digestdigital things arent looking too great here either  can Whatever expect anything less Laughing Out Loud At least its the weekend ',
#  'Finally get to be in bed  good night tweeties',
#  'anishkochar bangaloretrance Thanks guys ',
#  'alistairbeech Fabulous Thank you for your support ',
#  'TurnUpTexas I really dont I love you so much ',
#  'Final Fantasy follow her Grand Touring KaraboM 10 loners this side please ',
#  'RiahanneNavarro and a charger ',
#  'This is so me  http//tco/9aqyX0UxuV',
#  'electricgecko Introducing a new word Versus altering the understanding of a word Kiss spreading either  The Great Problem ',
#  'JAOlivar0731  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Final Fantasy my Wooftastic TWOOFS hope you have a supa Ass weekend \nMyPackofWolves\nSkythegsd\nhelvellyn\nBennyBoygr\nhttp//tco/fIYPR3t2Ai',
#  'clivewalker near enough to Dartmoor ',
#  'buymobileshelp I am Going to stay with the gold colour Hopefully it will come soon Thank you anyway ',
#  'TaylorMarisa Follow back  ',
#  'ijnmikky Cocaine Only Kidding D',
#  'Someday Very so know ',
#  'SmilingGirly  You Are my dii And i cant forget my Sister ',
#  'Just Got Home For Real smf Amplifier Ft With My girl lt3 ',
# ...
#  'The Group Of Close Friends bought me skins for my Birthday D',
#  'awadkum  Just chant Jai I Trust And Love You 100/times fast  BJP4India AmitShahOffice narendramodi',
#  'Heeeeyyy Can all of you follow my fan account KINGT0MLINS0N \n\nThank you ',
#  'leonrestaurants in the Are You OK ',
#  'JEDIEV11 thank you D',
#  'Blahkumaran WHOA National Institute of Clinical Excellence National Institute of Clinical Excellence ',
#  'cuteHiddlesmile You are welcome  ♥',
#  'lucahollic good and you  ',
#  'And heres mayankw14s ★★★★ review http//tco/wNVIPDDRe6 relief Were literally overwhelmed ',
#  'PatoFer222 Hello Would you like an imPastel concert Let me know your city and country and Cool tight etc start working on it Thanks ',
#  'Anaateresaa you Amplifier the baby😊😊😊 next time  its my house  I have it whenever ',
#  'TfLWaystoPay got it thanks Grin ',
#  'jonathanhobbs71 Have you encouraged your employer on board http//tco/sczAWaxEW0 or stuck a poster up http//tco/J024E6Dwvk ',
#  'MsKristinKreuk Hugs ang Kisses from the philippines ',
#  'Ive entered to WIN a huge BlueMicrophones package from CazuaLLUK Amplifier Marzbargaming  ENTER HERE https//tco/yRlT7jltqP Giveaway',
#  'JimEdwards yes it works now ',
#  'reyesreynaldoz  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Hello BridgeHouseThel  great to connect Whatever specialise in thermal imaging surveys – here if you need United States ',
#  'juanchavarin52 taliagarcia yeah so you can bruise my Make fun of again ',
#  'PallaviRuhail BhaktisBanter FlipkartFashionFriday 😀😁😂😃😄😅😉 No Offence No Offence wont give Drop Everything And Read dont worry ',
#  'TombRaider hype thought you might like this MelonieMac D http//tco/aXxprx1PRz',
#  'Other Half Me Other Half Me Other Half my its TheJuiceInTheMix President of the United States rela talliaoyando in the building  HomeboyzRadio DJBashKenya',
#  'Unfair priority match  hahaha',
#  'dxuntlesslarry fback ',
#  "HelpingGroupDms I want Harry Don't Mind Before Christ I Want to give a surprise to my friend for her birthday I just Want to make her happy ",
#  'Is now not an opportune time To collapse chaotic Cosas lt note the alliteration   NomalangaSA barrybateman AndileMlondo',
#  'sungjookxm going Very so oppayaa Hows yours D',
#  'khalidALSALEM Azizsm Whatever did our best as you want body ',
#  'NatGeo new show You cant lick Your A pound of marijuana seems interesting',
#  'Statistics for the day have arrived 7 new followers and No Offence unfollowers  via http//tco/C6u8lINDwD',
#  '“MileyCyrus Emu is Very happy thank you  http//tco/l5Xyt9EM6G” creampuffshinee',
#  'Woke up Your trentowers Favorite my A post on Twitter this made my day  now just luketurner89 😂😂 http//tco/oGw5sVij7G',
#  'Remember you dont need peoples approval when you have Gods approval ',
#  'and jisung is the kid sunshine   https//tco/LBjXDWIAPE',
#  'TheLlamaverse Married Man okay thanks ',
#  'noodles78 Message United States right here Nicola and Whatever can forward this on  Brighten up our day D Helen',
#  'dreyaniks  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'sunofsides Congratulations ',
#  'gunnersx4 Hello Brian Cool tight etc  get it shipped today for you and it can take between 23 weeks to Australia Many thanks  http//tco/IBoe0e1aXt',
#  'JanPrince63 AWonderBall was good fun at the time but the Online bones are now a creaking ',
#  'Mokhenerale What abUtI WelcOmE to TweetLandLol Penny',
#  'davidc79 Thanks And Android support in by Xmas ',
#  'phedran A great Skyblock stream too ',
#  'this is why I am standing and always being a Belieber  its all bcause of him justinbieber 2009 until Die ',
#  'BOHEffy I am streaming now on Twitch Join D\nhttp//www/twitchtv/lockedbeast1',
#  'BRBCODY it was a sympathy laugh ',
#  'huskarnana who would you like  Hugs & Kisses',
#  'DrtyChimichanga Amazing D',
#  'kimtaaeyeonss unnieeee',
#  'Tonight is the Night   nuka penacova djset free Electronic Dance Music kizomba latinhouse HouseMusic portugal2015 summer http//tco/m5WqWKfqs3',
#  'moonlight69 Very so youre in for a wild ride Getting Things Done',
#  'TokyoTantra Hahaha tell me anytime you Want to taste it Other Half with Your address to send it ',
#  'mtnza mtn8 thanks team yellow  MTN8',
#  'Acsxy Maganda You look very pretty with short hair Someone D',
#  'MistressSaphire Good morning to you gorgeous Mistress Saphire ',
#  'AwareGinGi I am at work and I am busy so I will help you once I finish and I am at home ',
#  'Thanks to amazing 4000 Followers on Instagram\nIf you´re not among them yet\nfeel free to connect  http//tco/ILy03AtJ83',
#  'Coconut Sambal Mussels Recipe  http//tco/FSfkpOwTpS',
#  'Thanks Kalin  http//tco/ihELksfJjT',
#  'Follow JaHz73 on Mixcloud \n\nhttps//tco/HviVk8rMmp',
#  'L0MLHES fback ',
#  'implodingpika Thankyou  Greetings from Australia ',
#  'MIKEYGEE110 I cant work out if this is sarcasm or not  i know some Chelsea supports think hes useless but when he comes on he does Only Kidding',
#  'IBePyari follow back ',
#  'aubreysablan I come back next Thursday Whatever can still Hang out out  hehe she said Hello love You',
#  'shaunamanda2012 Benson is gorgeous Thank you so much for sharing him with United States  You can also enter on our Facebook too',
#  'ItsLukeEv you look a Cool 16/17 ',
#  'Great night D',
#  'primaverabella 30°C 😜\xa0so Whatever just should change for few days and all is good ',
#  'Attention Deficit Disorder me on Snapchat  MaryHicks18 snapchat kikmeboys photooftheday fuck chat musicbiz sheskindahot  http//tco/plFpD86iEq',
#  'fleekile mbalula he said i repeat i love my south africa ',
#  'when your friend is making fun of the fact that your mexican so you Ugly his feelings thatll leave him scarred for life ',
#  'SophiaDelPizzo its my office today ',
#  'jeremygutsche Whatever like this amazing donut recipe Whatever share with foiegras lovers ',
#  'Despite the weather today the wedding is going to be beautiful ',
#  'Where Was Tony Stark   From Incredible Tony Pictures http//tco/uwhGYM0BWb http//tco/pHp6OcHlXH',
#  'To Stay In Touch and write poems or stories thats been bubbling in my head ',
#  'Last night  http//tco/8EDHMc2tiJ',
#  'EmilySmith91 Dale send a billion Keep It Simple Stupid to her  Have a magical day',
#  'mcllary That might work  Have a great weekend Original Poster',
#  "Smile its friday  Thank God It's Friday weekend http//tco/L6KxKEAl75",
#  'i will not cast my vote in next elections  JCReport',
#  'PebbleHelp Have Finished Thank you for your A post on Twitter ',
#  'JILLCLARK1808 BigAllfc SuePeace1 michell47881905 Bevanns susanhorgan1 Other Half piggin just go will Your give United States some Goodbye ',
#  'alElizabeth Appreciate the follow  have you heard of our botanical soaps',
#  'Ashton5SOS 5SOS love You To ',
#  'Missed a period upload Freshly done/3weeks old healed ',
#  'ImMsKittenns Other Half I was in bed haha I cant sleep though My day was too exciting ',
#  'TOBMAST3R inspchin koeitecmoeurope TanikoHorigome GoldxFierce Kronin1 Addictrian chako33 MatthewRumple Thanks Tobibro D',
#  'nikimcglynn How good is that I think it was my first Internet Service Provider too ',
#  'tessasmith4evr BlueBellEMS Very so steel some from the BlueBellEMS next Wednesday and see what its like',
#  'Hello hi there ',
#  'camerondallas definitely loves making people smile Because I swear since I met him earlier I havent stopped smiling  i love you Computer-Aided Manufacturing 😭❤️',
#  'SabihaMahmoud  except for her Lord mashaAllah ',
#  'NeilWhoreAnn some French fans made a movie about the WWAT in France last year with our videos and photos ',
#  'maxpen1 It has been fixed thanks for your feedback ',
#  'Thanks to everyone who came to the stream D Hope you guys enjoyed Night all',
#  'siddichan Twitch YAAAAAAAAY Thanks ',
#  'Looking forward to reviewing ours   https//tco/y8SUBXjqXk',
#  'Thank you Beiruting ',
#  'coolkidsftnjh fback ',
#  'Thanks for updating your profile page AlexaPoppe   http//tco/JK3NSXIRMe',
#  'Lovely coffee  CoffeesToGo1',
#  'Heres a Someone panda to make your day  http//tco/zCaWqrjSvr http//tco/FuZNhjGWD7',
#  'x0lovestephi thank you eonnie ',
#  'stokebrisbane Hello Saw who You follow and thought You might like Dark https//tco/CFl0s5hwWw Please let United States know what You think ',
#  'Polishedteeth my favourite too  ciatelondon Cream Soda ',
#  'I love my body when its fuller and shit even when its not Laughing Out Loud I am just happy to be healthy  happy to be happy 💓',
#  'Rettweet  http//tco/l6T0rx7bEf',
#  'DianaaOrtizz the real MVG MOST VALUABLE GIRLFRIEND for staying up with me till the Madrid game starts ',
#  'OLXOHayoung96 sore You ',
#  'tmhcuddly I am so excited Whatever should definitely meet up ',
#  'morriskid are you coming to Bergerac  Have the first team left any u21s Identity know of checking for chants ',
#  'rizwanism  just a Nice of food Left to the individuals',
#  'VickiCartagena The episode is excellent so far I love Adam Beachs movies Amplifier showsIm looking forward to seeing Suicide Squad next year',
#  'Growing very fond of Christopher didnt like him initially because he was Thinking too highly of yourself and didnt really prove it but his attitudes improving D',
#  "GlenOcsko sounds good Can you Don't Mind me your email address Will suggest some dates for a coffee ",
#  'forlodge1 It is indeed  many thanks ',
#  'Just smile even your in Pain  http//tco/AxTiqf0xek',
#  'Hello happys http//tco/AGiLlxJdbi',
#  'Funny Intelligent strong and funny Just funny  https//tco/IqJwYRF52C',
#  'Hello  Get Youth Job Opportunities follow gtgt tolajobjobs me1campbell',
#  'mokwepa No Offence other than it using Counter-Strike ',
#  'you ever watch certain peoples snapchat over and over again Before Christ i know i do ',
#  'IbnNabih1 thats all Only Kidding I know your busy ',
#  'Last To exams ',
#  'forgot You were up   https//tco/Or6eATWDjm',
#  'Fun fact I love meeting new people ',
#  'jaseygalore I know the homebased office busy feeling  Pity about your knee  what happened',
#  "SALE FLEUR DRESS CREAM Readystockhijabmart\nIDR 325000 Grand Touring I Don't Remember 200000  http//tco/AGp51NQMbS",
#  'pprabha014 Thankyou ',
#  'fernandeznoemi4  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'Is Tompolo meeting aimed at stopping the sale of the oil that Whatever cannot find buyers for D',
#  'Centerfxld thats true johngreen doesnt disappoint Looking forward to Money Towns ',
#  'Thats all I need to know is that everything is going to be okay ',
#  'LTBeautyBlog FDNCoffee I say less slacking Amplifier getting cracking ',
#  'JulieWestern I dont know the name but it is particularly striking Happy days ',
#  'misshollylou Hello hi heres your invite to join Scope as an influencer   http//tco/ipJ2yOiGet',
#  'DeewaniVeronica 31 My Good Mam Penny',
#  'FrancesBeeton Lovely looking Kilo of cocaine Black Entertainment Television it tastes good too ',
#  'FeyTyaz Follback You ',
#  'dalenaha1 so I found this last night lets just say there was an instant stiffening of my interest  https//tco/sw5O1Bz4y9',
#  'Rettweet  http//tco/zBOvLw0y5S',
#  'CHUBANHES fback ',
#  'Rettweet  http//tco/CGTjR664Kj',
#  'rickyfebs Follback You ',
#  'Got Secrets of Grindea Courier of the Crypts and possibly some Arma 3 to record today Exclamation of suprise or shock And a new game that looks like Limbo ',
#  'siaramelatienza  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'MyriadPhoto  thanks for retweeting madsenjewellery orchard Alright show have a Very really weekend ',
#  'Karachi ka Venice after rains  rizzjavaid “JaagAlerts Several parts of Karachi witness accumulated rain waterhttp//tco/Wionr1evBo”',
#  'maroon cocktail dresses http//tco/Ioj5YzNRwu MidiDresses for filipinaniah  http//tco/Vj1U5fIzBw',
#  'IamPatmae fback po ',
#  '0100 real quick ',
#  'IronVein Morning   Mine is 1100D Usually autofocus I only use manual for  really close up like shooting veins on crackle glaze ',
#  'the new layout looks Something really bad  \ng',
#  'Thanks for connecting garrowlscq Hope youre having an Great Day  Have a social/website question Just ask ',
#  'Tweetnesian pake ',
#  'gabrielaliuw Hello Whatever made some changes in our design hope you like it  https//tco/EXt098Yq1b',
#  'joim me while I feed the troops  https//tco/ZlcsRuUpPY via audioBoom',
#  'Any brands wanting me to review BEAUTY products on my Weblog mail me at ladolcevitainluxembourghotmailcom prrequest journorequest ',
#  'TheMadStork Follback You ',
#  'SSalchli Good luck Shaun ',
#  'madziucha5 yes he is ',
#  "Anyone who wants to be added to the Back On Topic just Don't Mind me  Back On Topic",
#  'ChloeGMoretz Chloe I watched Let me in yesterday and you were really Amazing Really talented and intelligent actress beautiful too ',
#  'hesfallenangel could i get some free solo  Dirty Money Syndicate Any to give away  Hugs & Kisses',
#  'TripVerse outboundapp thanks for sharing Wishing you a Very weekend ',
#  'Hello juan sending you a Great Hello from Houston Thanks  Ive been a fan of jenni  and the family for years  I stumble upon a video of you',
#  'padaleckbye No Offence probnice choker By The Way ',
#  'seoulsjin seouljins seouljins  both are fine To Be Honest',
#  'Photoset sadomasochistsparadise Wynter bottoms and an outtake  Sadomasochist’s Paradise Cuties http//tco/GNW1lwjFK1',
#  'You make my day by just smiling ',
#  'ghostkidluke fback ',
#  'itsRebeccaRayne D Thank You Baby',
#  'Please enjoy this clip of me losing my shit during cypher  http//tco/8FIyPQ6kkn',
#  'athrawestokio AdeccoWaytoWork AdeccoJapan next week i will be at my office  so lets go ',
#  'DanielCWest thank you for following me D',
#  'Statistics for the day have arrived To new followers and No Offence unfollowers  via http//tco/e644DJI0zw',
#  'purehaire Amen Thanks ',
#  'Hello Below Average Mentality  BarsAndMelody \nCan you follow my bestfriend 969Horan696  \nShe loves you a lot  \nSee you in Warsaw lt3 \nLove you lt3 x32',
#  'shyayen  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'DrenchinWine 2fai ChompuKusuma Money girl D',
#  'gculloty87 I know would of been lovely to have her in that Picture  Kiss',
#  'adnanCad Planted people are allowed to do any thing and every thing Penny',
#  'mRpOrTeR7 This Corner is so fucking Heroin Getting addicted to it\nGreat Job D',
#  'My Baby Girl  http//tco/S0IiU35MWw',
#  'Hello hi Hello hi D',
#  'NickTheBullsFan CashNastyGaming still suck at editing but if this turns into something special I owe it to you guys ',
#  'ayokejkt Visit my Weblog http//tco/UzOAqroWKx thanks D',
#  'daannymoncada breannelaflare YOURE UGLY DANIEL is it good Mad',
#  'Happy Birthday Cinemainmygenes  Saar\nHave a great year ahead ',
#  'LucyLuxx Thought you might I saw it and I loved the verse The butterfly part was just a bonus ',
#  'Thank you  Only Kidding \nHave fun\nanvy2446 4HUMANITEEs SexyAF12 kikbella adasamper RachelLFilsoof\nEnjoy day You all\nhttp//tco/5Y5OAESAzv',
#  'Very so good morning D',
#  'palakspatel would you follow me',
#  'Busy productive day filled with a few tears but hours and hours of laughter Today was a good day ',
#  "17bljpk Hello You have 5sos tickets Don't Mind me ",
#  'Yummmyyy  — eating dosa',
#  'bbcdoctorwho so do I D',
#  'MegLovesGames its probably easier to meet at the station Unless you particularly want to show me your house ',
#  'A Huge Amplifier Warm Welcome to VodkaBlond ',
#  'ACHI I am busy next week because of our exams Hope you understand that I cant A post on Twitter youuu Bawi ako queenesther  esthercarodan',
#  'LeeMcKenzieTV Looking sharp ',
#  'xWinnerMino yess I am 1 year younger than You  No Offence wonder youre huge boy',
#  'I am playing Brain Dots   BrainDots\nhttp//tco/ilDzDRHf9d http//tco/VTXNFCPFuI',
#  'Sarcastic laugh All in One Love picture  http//tco/IgLPwLvSfz',
#  'Galatasaray Podolski10 is ready  Poldi Cimbom',
#  'LuvSocialMedia Thanks for the share ',
#  'LOSTCHILLHORAN fback ',
#  '24f567234e3c410  follow jnlazts Amplifier http//tco/RCvcYYO0Iq follow You back ',
#  'graphure Happy birthday Friend D',
#  'waterrat77 Thank you ',
#  'Exhale depressedly Whykaysbeauty Bruhhh“Dopjones Call me daddy One Love more time ”',
#  ...]

# %%
test_x_ab=[]
for tweet in test_x :
    test_x_ab.append(abbreviation(tweet))

# %%
# create frequency dictionary
freqs = build_freqs(train_x_ab, train_y)

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x_ab), 3))
for i in range(len(train_x_ab)):
    X[i, :]= extract_features(train_x_ab[i], freqs)

# training labels corresponding to X
Y = train_y
print(X[i, :])
# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# [  1. 220. 398.]
# The cost after training is 0.68269824.
# The resulting vector of weights is [-2e-08, 0.00012366, 1.46e-06]

# %%
#test
tmp_accuracy = test_logistic_regression(test_x_ab, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.5065
